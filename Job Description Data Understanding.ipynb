# %%
import numpy as np
import pandas as pd

# Hugging Face
from datasets import load_dataset
dataset = load_dataset("jacob-hugging-face/job-descriptions", split="train")
# Out:
# Found cached dataset csv (C:/Users/Rahulram/.cache/huggingface/datasets/jacob-hugging-face___csv/jacob-hugging-face--job-descriptions-0f4bc36642a984ba/0.0.0/eea64c71ca8b46dd3f537ed218fc9bf495d5707789152eb2764f5c78fa66d59d)

# %% [markdown]
# ### Dataset Creation
#
# - Select 10 Random Job Descriptions to work on. (Seed = 69)
# - Luckily, seed 69 generates a mixture of job descriptions.

# %%
df = pd.DataFrame(dataset)
df = df.sample(n = 10, random_state = 69)
df
# Out:
#                              company_name  \
# 658                        HCA Healthcare
# 642                 Major League Baseball
# 377                Teaneck Public Schools
# 264                                  Volt
# 587                      Lear Corporation
# 515                   Sunrise Systems Inc
# 441               Brooklyn Public Library
# 688  DGA Security   New York, NY   Hybrid
# 20                     Ascend Innovations
# 26                          Owner Actions
#
#                                        job_description  \
# 658  registrar\n\n\nhca florida memorial hospital\n...
# 642  want your work displayed across major league b...
# 377   jobid \n\nposition type\n\ndistrictart\n\ndat...
# 264  volt has partnered with a leading manufacturin...
# 587  we are hiring a customer service representativ...
# 515  our client a leading medical device manufactur...
# 441  overview\n\nthe systems administrator works as...
# ...

# %%
df.to_csv("Job_Descriptions.csv")
